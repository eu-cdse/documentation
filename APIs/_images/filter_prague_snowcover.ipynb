# %% [markdown]
# # Instructions for Using the STAC API Extensions: filter with more than one operator, sort, fields
#
# This notebook provides a step-by-step guide on how to use the STAC (SpatioTemporal Asset Catalog) API to search for Sentinel-2 Level 2A data within a specified time range and geographic area. It demonstrates how to leverage STAC extensions for filtering, selecting, and sorting data based on specific parameters.
#
# In the presented example, we will choose Prague, the capital of the Czech Republic as the study area, focusing on the period from November 2017 to April 2024, in order to illustrate images with cloud cover less than 50% and snow cover greater than 40%, highlighting areas with significant snow coverage and relatively low cloud cover.
#
# In this case, we will show how to use the `filter` extension to construct the appropriate parameters for selecting data based on both cloud cover and snow cover conditions.

# %% [markdown]
# ## Libraries
#
# First, ensure all required packages are installed and imported.

# %%
# !pip install stackstac && pip install pystac_client && pip install geogif
import pystac_client
import geogif
import stackstac
import os
# Out:
# Requirement already satisfied: stackstac in /opt/conda/envs/geo/lib/python3.11/site-packages (0.5.1)
# Requirement already satisfied: dask>=2022.1.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask[array]>=2022.1.1->stackstac) (2024.11.2)
# Requirement already satisfied: numpy<3,>1.23 in /opt/conda/envs/geo/lib/python3.11/site-packages (from stackstac) (1.26.4)
# Requirement already satisfied: pandas<3,>=2 in /opt/conda/envs/geo/lib/python3.11/site-packages (from stackstac) (2.2.3)
# Requirement already satisfied: pyproj<4.0.0,>=3.0.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from stackstac) (3.6.1)
# Requirement already satisfied: rasterio<2.0.0,>=1.3.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from stackstac) (1.3.10)
# Requirement already satisfied: xarray>=0.18 in /opt/conda/envs/geo/lib/python3.11/site-packages (from stackstac) (2024.5.0)
# Requirement already satisfied: click>=8.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (2021.11.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (8.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pandas<3,>=2->stackstac) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pandas<3,>=2->stackstac) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pandas<3,>=2->stackstac) (2024.2)
# Requirement already satisfied: certifi in /opt/conda/envs/geo/lib/python3.11/site-packages (from pyproj<4.0.0,>=3.0.0->stackstac) (2024.8.30)
# Requirement already satisfied: affine in /opt/conda/envs/geo/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/envs/geo/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (24.2.0)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/envs/geo/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/conda/envs/geo/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (1.1.1)
# Requirement already satisfied: setuptools in /opt/conda/envs/geo/lib/python3.11/site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (75.6.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/envs/geo/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (3.21.0)
# Requirement already satisfied: locket in /opt/conda/envs/geo/lib/python3.11/site-packages (from partd>=1.4.0->dask>=2022.1.1->dask[array]>=2022.1.1->stackstac) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/geo/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=2->stackstac) (1.16.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /opt/conda/envs/geo/lib/python3.11/site-packages (from snuggs>=1.4.1->rasterio<2.0.0,>=1.3.0->stackstac) (3.2.0)
# Requirement already satisfied: pystac_client in /opt/conda/envs/geo/lib/python3.11/site-packages (0.8.2)
# Requirement already satisfied: requests>=2.28.2 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pystac_client) (2.32.3)
# Requirement already satisfied: pystac>=1.10.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac_client) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pystac_client) (2.9.0.post0)
# Requirement already satisfied: jsonschema~=4.18 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pystac[validation]>=1.10.0->pystac_client) (4.23.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/geo/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pystac_client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/geo/lib/python3.11/site-packages (from requests>=2.28.2->pystac_client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/geo/lib/python3.11/site-packages (from requests>=2.28.2->pystac_client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from requests>=2.28.2->pystac_client) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/geo/lib/python3.11/site-packages (from requests>=2.28.2->pystac_client) (2024.8.30)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/geo/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/geo/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client) (0.21.0)
# Requirement already satisfied: geogif in /opt/conda/envs/geo/lib/python3.11/site-packages (0.2)
# Requirement already satisfied: Pillow<11.0,>=10.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from geogif) (10.4.0)
# Requirement already satisfied: dask>=2021.4.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask[delayed]>=2021.4.1->geogif) (2024.11.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.4.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from geogif) (3.9.2)
# Requirement already satisfied: numpy<2.0.0,>=1.20.2 in /opt/conda/envs/geo/lib/python3.11/site-packages (from geogif) (1.26.4)
# Requirement already satisfied: xarray>=0.18 in /opt/conda/envs/geo/lib/python3.11/site-packages (from geogif) (2024.5.0)
# Requirement already satisfied: click>=8.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (2021.11.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (8.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.4.1->geogif) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/geo/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.4.1->geogif) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.4.1->geogif) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.4.1->geogif) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.4.1->geogif) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/geo/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.4.1->geogif) (2.9.0.post0)
# Requirement already satisfied: pandas>=2.0 in /opt/conda/envs/geo/lib/python3.11/site-packages (from xarray>=0.18->geogif) (2.2.3)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/envs/geo/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pandas>=2.0->xarray>=0.18->geogif) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/geo/lib/python3.11/site-packages (from pandas>=2.0->xarray>=0.18->geogif) (2024.2)
# Requirement already satisfied: locket in /opt/conda/envs/geo/lib/python3.11/site-packages (from partd>=1.4.0->dask>=2021.4.1->dask[delayed]>=2021.4.1->geogif) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/geo/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.4.1->geogif) (1.16.0)

# %% [markdown]
# * `pystac_client`, `stackstack`: A Python library for working with STAC catalogs. It enables interaction with STAC services, reading catalog information, and searching for products based on specified parameters.
# * `geogif`: A Python library for creating animated GIFs from data cubes, enabling the visualization of time series data in a dynamic and engaging format.
# * `os`: A standard Python package that provides functionality for interacting with the operating system, including accessing environment variables and managing file paths. It is often used for authentication and setting up access credentials for various APIs and services, such as STAC.

# %% [markdown]
# ## S3 Credentials
#
# In order to access the data from CloudFerro's catalog, authentication is required. To facilitate this, you will need to create an account in the Copernicus Data Space Ecosystem (CDSE). The registration process is quick and can be completed in under 60 seconds. You can find the registration link here: https://documentation.dataspace.copernicus.eu/APIs/S3.html.
#
# Once you have created an account, the same URL will redirect you to the section where you can generate your `S3 Credentials`. To do this, simply click the `Add Credential` button. This will allow you to define an expiration date for your credentials.
#
# After selecting the expiration date, you will have successfully created your own S3 credentials. Please make sure to save the secret key at this point, as it will not be displayed again.
#
# Now that you have your S3 credentials, you can use them to connect to the STAC catalog. By utilizing the `os` package, you will set environment variables to authenticate yourself as a valid user for the S3 protocol.
#
# The only variables you need to configure are:
# * `AWS_ACCESS_KEY_ID`
# * `AWS_SECRET_ACCESS_KEY`.

# %%
os.environ['GDAL_HTTP_TCP_KEEPALIVE'] = "YES"
os.environ['AWS_S3_ENDPOINT'] = "eodata.dataspace.copernicus.eu"
os.environ['AWS_ACCESS_KEY_ID'] = "your_access_key" # !
os.environ['AWS_SECRET_ACCESS_KEY'] = "your_secret_access_key" # !
os.environ['AWS_HTTPS'] = "YES"
os.environ['AWS_VIRTUAL_HOSTING'] = "FALSE"
os.environ['GDAL_HTTP_UNSAFESSL'] = "YES"

# %% [markdown]
# ## Connecting to the STAC Catalog
#
# We connect to the Copernicus STAC catalog, available at the endpoint: https://stac.dataspace.copernicus.eu/v1.

# %%
URL = "https://stac.dataspace.copernicus.eu/v1"
cat = pystac_client.Client.open(URL)
cat.add_conforms_to("ITEM_SEARCH")

# %% [markdown]
# ## Defining the Area of Interest (AOI)
#
# We define the area as a polygon based on geographical coordinates in GeoJSON format.
# * `type`: Geometry type, in this case, a polygon.
# * `coordinates`: A list of coordinates defining the area.

# %%
geom = {
    "type": "Polygon",
    "coordinates": [
        [
            [14.254, 50.014],
            [14.587, 50.014],
            [14.587, 50.133],
            [14.254, 50.133],
            [14.254, 50.014],
        ]
    ],
}

# %% [markdown]
# ## Defining Search Parameters
#
# In this section, we define and combine parameters into a single dictionary for passing to the search function:
# * `max_items`: The maximum number of results to retrieve.
# * `collections`: The STAC collection (e.g., Sentinel-2 Level 2A data).
# * `datetime`: Time range in YYYY-MM-DD/YYYY-MM-DD format.
# * `intersects`: The previously defined area of interest.
# * `filter`: Filters the data based on specific properties. JSON object with an operator (op) and arguments (args), which specify the filtering condition (e.g., cloud_cover < 10).
# * `sortby`: Sorts results (e.g., by the eo:cloud_cover property in ascending order).
# * `fields`: Specifies which fields to exclude (e.g., geometry).

# %%
params = {
    "max_items": 100,
    "collections": "sentinel-2-l2a",
    "datetime": "2017-11-01/2024-04-01",
    "intersects": geom,
    "filter": {
    "op": "and",
    "args": [
        {
            "op": "lte",
            "args": [{"property": "eo:cloud_cover"}, 50]
        },
        {
            "op": "gte",
            "args": [{"property": "eo:snow_cover"}, 40]
        }
    ]
},
    "sortby": "properties.eo:snow_cover",
    "fields": {"exclude": ["geometry"]}
}

# %% [markdown]
# ## Searching the Catalog
#
# We query the catalog and convert the results into a list of dictionaries.

# %%
items = list(cat.search(**params).items_as_dicts())

# %% [markdown]
# ## Creating DataCube from STAC
#
# After performing the search, we can create a STACK object from the obtained items. In the definition of the STACK object, the following parameters must be declared:
#
# * `items`: The STAC items that will be included in the stack object.
# * `resolution`: The desired output resolution.
# * `bounds_latlon`: The spatial bounding box of the output, given in degrees of latitude and longitude.
# * `chunksize`: The chunk size to be used for the Dask array.
# * `epsg`: The EPSG code for the coordinate reference system to which the data will be reprojected.
# * `gdal_env`: GDAL configuration options to be used when opening and reading the datasets.

# %%
stack = stackstac.stack(
    items=items,
    resolution=(20, 20),
    bounds_latlon=(14.254, 50.014, 14.587, 50.133),
    chunksize=98304,
    epsg=32634, 
    gdal_env=stackstac.DEFAULT_GDAL_ENV.updated({
        'GDAL_NUM_THREADS': -1,
        'GDAL_HTTP_UNSAFESSL': 'YES',
        'GDAL_HTTP_TCP_KEEPALIVE': 'YES',
        'AWS_VIRTUAL_HOSTING': 'FALSE',
        'AWS_HTTPS': 'YES',
    })
)

# %% [markdown]
# ## Band selection
#
# In this step, we are selecting the specific spectral bands from the stacked satellite data that correspond to the Red, Green, and Blue (RGB) channels. These bands are essential for creating a true-color composite image, which represents the Earth’s surface in a way similar to how it would appear to the human eye.
#
# The bands we select to be used to create an RGB image for visualisation, are:
# * `B04_20m`: Red band
# * `B03_20m`: Green band
# * `B02_20m`: Blue band

# %%
rgb = stack.sel(band=["B04_20m", "B03_20m", "B02_20m"])

# %% [markdown]
# ## Displaying results as a GIF
#
# In this step, we create a GIF to visualize the filtered results. We obtain a sequence of satellite images showing how the snow cover in the selected area evolved over the years 2017–2024, based on the specified parameters: snow cover greater than or equal to 40% and cloud cover less than or equal to 50%.

# %%
gif = geogif.dgif(rgb, fps=1).compute()
gif

# %% [markdown]
# ## Displaying Snow Cover for Results
#
# We extract the `eo:snow_cover` values for each item and display them. The previously used `sortby` extension allows for automatic sorting of the results based on the selected parameter, in this case, snow cover.

# %%
snow_cover_values = [item['properties']['eo:snow_cover'] for item in items]
snow_cover_values
# Out:
# [43.29, 51.97, 65.09, 69.35, 83.41]
